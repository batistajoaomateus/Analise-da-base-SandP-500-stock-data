# %% [markdown]
# <a href="https://colab.research.google.com/github/batistajoaomateus/Analise-da-base-SandP-500-stock-data/blob/main/PROJETO_APLICADO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd
from google.colab import drive
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
caminho_arquivo_excel = '/content/BASE 1 - ACOMPANHAMENTO DE LOJAS.xlsx'

# %%
df = pd.read_excel(caminho_arquivo_excel)

# %%
df.head()
# Out:
#    UF  id cidade cidade  id empresa     status categoria  gmv (mês atual)  \
# 0  MT       83.0      X      3293.0  Publicada         A         56060.51
# 1  MT       83.0      X      3300.0  Publicada         C          8207.00
# 2  MT       83.0      X      3301.0  Publicada         A         80731.00
# 3  MT       83.0      X      3302.0  Publicada         A        207155.19
# 4  MT       83.0      X      3340.0  Encerrada       NaN          7105.50
#
#    gmv (mês anterior)     % mom  pedidos (mês atual)  ...   % mom.1  \
# 0             7222.03  6.762431                990.0  ...  6.734375
# 1             1575.00  4.210794                151.0  ...  4.392857
# 2            14663.00  4.505763                946.0  ...  4.405714
# 3            30213.70  5.856333               2375.0  ...  5.709040
# 4                 NaN  0.000000                133.0  ...  0.000000
#
#    TM (mês atual)  TM (mês anterior)   % mom.2  gmv por dia (mês atual)  \
# ...

# %%
df.describe()
# Out:
#        id cidade    id empresa  gmv (mês atual)  gmv (mês anterior)  \
# count      297.0    297.000000       297.000000          233.000000
# mean        83.0  37349.461279     19112.051515         3724.102961
# std          0.0  17801.908720     32669.973405         5569.276640
# min         83.0   3293.000000        29.000000           15.000000
# 25%         83.0  20493.000000      2087.930000          657.000000
# 50%         83.0  42279.000000      7061.600000         1793.500000
# 75%         83.0  54792.000000     22609.980000         4513.590000
# max         83.0  58774.000000    302407.100000        49818.200000
#
#             % mom  pedidos (mês atual)  pedidos (mês anterior)     % mom.1  \
# count  297.000000           297.000000              233.000000  297.000000
# mean     4.604599           312.848485               61.223176    4.611845
# std      4.737770           461.896210               77.423221    4.408891
# ...

# %%
# Carregue o DataFrame existente a partir de um arquivo Excel (se já não estiver carregado)
data = pd.read_excel('BASE 2 - DADOS LOJAS.xlsx')

# %%
# Carregar a nova base de dados do Excel
nova_base = pd.read_excel('BASE 2 - DADOS LOJAS.xlsx')

# %%
# Juntando os DataFrames usando a função concat
# axis=0 para empilhar as linhas, axis=1 para concatenar colunas
data = pd.concat([data, nova_base], axis=1)  # Você pode escolher axis=1 se as colunas corresponderem

# %%
# Verificando se a junção foi bem-sucedida
print(data.head())  # Visualize os primeiros registros para garantir que os dados foram adicionados corretamente
# Out:
#                                    uuid  id cidade       tipo  id empresa  \
# 0  11ec22d0-7148-28e2-a597-12ef5f61c2cd       83.0  Acelerada     47889.0
# 1  11ea5fd3-94a9-bc75-a09f-12f5b75dabdf       83.0  Acelerada     24644.0
# 2  11ebebad-abbd-90c4-bdb8-12ef5f61c2cd       83.0  Acelerada     46276.0
# 3  11eb81f7-615b-ec1a-bdb8-12ef5f61c2cd       83.0  Acelerada     41490.0
# 4  11e94983-bb06-24ca-b906-026798b2501a       83.0  Acelerada     15471.0
#
#   cluster     vertical fullservice    criação status descrição  removida  ...  \
# 0     NaN  Restaurante         não 2021-10-01           CLOSED       0.0  ...
# 1     NaN  Restaurante         não 2020-03-06           CLOSED       0.0  ...
# 2     NaN  Restaurante         não 2021-07-23           CLOSED       0.0  ...
# 3     NaN  Restaurante         não 2021-03-10         rascunho       0.0  ...
# 4       A  Restaurante         não 2019-03-18        publicada       0.0  ...
#
# ...

# %%
df.head()
# Out:
#    UF  id cidade cidade  id empresa     status categoria  gmv (mês atual)  \
# 0  MT       83.0      X      3293.0  Publicada         A         56060.51
# 1  MT       83.0      X      3300.0  Publicada         C          8207.00
# 2  MT       83.0      X      3301.0  Publicada         A         80731.00
# 3  MT       83.0      X      3302.0  Publicada         A        207155.19
# 4  MT       83.0      X      3340.0  Encerrada       NaN          7105.50
#
#    gmv (mês anterior)     % mom  pedidos (mês atual)  ...   % mom.1  \
# 0             7222.03  6.762431                990.0  ...  6.734375
# 1             1575.00  4.210794                151.0  ...  4.392857
# 2            14663.00  4.505763                946.0  ...  4.405714
# 3            30213.70  5.856333               2375.0  ...  5.709040
# 4                 NaN  0.000000                133.0  ...  0.000000
#
#    TM (mês atual)  TM (mês anterior)   % mom.2  gmv por dia (mês atual)  \
# ...
